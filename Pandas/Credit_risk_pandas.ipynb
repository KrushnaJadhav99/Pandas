# %%
import pandas as pd

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.shape
# Out:
# (981, 13)

# %%
cr.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#how to select individual columns

# %%
cr.ApplicantIncome.describe()
# Out:
# count      981.000000
# mean      5179.795107
# std       5695.104533
# min          0.000000
# 25%       2875.000000
# 50%       3800.000000
# 75%       5516.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
cr['ApplicantIncome'].describe()
# Out:
# count      981.000000
# mean      5179.795107
# std       5695.104533
# min          0.000000
# 25%       2875.000000
# 50%       3800.000000
# 75%       5516.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
cr.Gender.describe()
# Out:
# count      957
# unique       2
# top       Male
# freq       775
# Name: Gender, dtype: object

# %%
cr.Property_Area.describe()
# Out:
# count           981
# unique            3
# top       Semiurban
# freq            349
# Name: Property_Area, dtype: object

# %%
cr.Gender.value_counts()
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
cr.Property_Area.value_counts()
# Out:
# Semiurban    349
# Urban        342
# Rural        290
# Name: Property_Area, dtype: int64

# %%
cr.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  956.000000       981.000000         981.000000  954.000000
# mean     0.881799      5179.795107        1601.916330  142.511530
# std      1.255623      5695.104533        2718.772806   77.421743
# min      0.000000         0.000000           0.000000    9.000000
# 25%      0.000000      2875.000000           0.000000  100.000000
# 50%      0.000000      3800.000000        1110.000000  126.000000
# 75%      2.000000      5516.000000        2365.000000  162.000000
# max      4.000000     81000.000000       41667.000000  700.000000
#
#        Loan_Amount_Term  Credit_History
# count        961.000000      902.000000
# mean         342.201873        0.835920
# std           65.100602        0.370553
# min            6.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %%
cr.describe(include='all')
# Out:
#          Loan_ID Gender Married  Dependents Education Self_Employed  \
# count        981    957     978  956.000000       981           926
# unique       981      2       2         NaN         2             2
# top     LP002139   Male     Yes         NaN  Graduate            No
# freq           1    775     631         NaN       763           807
# mean         NaN    NaN     NaN    0.881799       NaN           NaN
# std          NaN    NaN     NaN    1.255623       NaN           NaN
# min          NaN    NaN     NaN    0.000000       NaN           NaN
# 25%          NaN    NaN     NaN    0.000000       NaN           NaN
# 50%          NaN    NaN     NaN    0.000000       NaN           NaN
# 75%          NaN    NaN     NaN    2.000000       NaN           NaN
# max          NaN    NaN     NaN    4.000000       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        981.000000         981.000000  954.000000        961.000000
# ...

# %%
cr.Gender.describe()
# Out:
# count      957
# unique       2
# top       Male
# freq       775
# Name: Gender, dtype: object

# %%
cr.Gender.value_counts()
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
#how to find the Null in the dataFrame

# %%
cr1 = cr.dropna()

# %%
cr1.shape
# Out:
# (769, 13)

# %%
cr.shape
# Out:
# (981, 13)

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.Credit_History.value_counts()
# Out:
# 1.0    754
# 0.0    148
# Name: Credit_History, dtype: int64

# %%
cr.Credit_History.value_counts()
# Out:
# 1.0    754
# 0.0    148
# Name: Credit_History, dtype: int64

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.Credit_History = cr.Credit_History.fillna(1)
cr.Gender = cr.Gender.fillna('Male')
cr.Married = cr.Married.fillna('No')
cr.Dependents = cr.Dependents.fillna(0)
cr.Self_Employed = cr.Self_Employed.fillna('Yes')
cr.LoanAmount = cr.LoanAmount.fillna(cr.LoanAmount.mean())
cr.Loan_Amount_Term = cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean())

# %%
cr.Dependents.value_counts()
# Out:
# 0.0    570
# 2.0    160
# 1.0    160
# 4.0     90
# 3.0      1
# Name: Dependents, dtype: int64

# %%
cr.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# Lets do the slicing dicing of DataFrame
# how to select rows and cols also based on requirement

# %%
cr.iloc[ [0,9,99,399,499], [0,2,5,8,9]] #iloc Stands for index Location.
# Out:
#       Loan_ID Married Self_Employed  LoanAmount  Loan_Amount_Term
# 0    LP001002      No            No   142.51153             360.0
# 9    LP001020     Yes            No   349.00000             360.0
# 99   LP001343     Yes            No   131.00000             360.0
# 399  LP002287      No            No   103.00000             360.0
# 499  LP002602      No            No   209.00000             360.0

# %%
cr2 = cr.iloc[ [0,9,99,399,499], [0,2,5,8,9]]

# %%
cr2
# Out:
#       Loan_ID Married Self_Employed  LoanAmount  Loan_Amount_Term
# 0    LP001002      No            No   142.51153             360.0
# 9    LP001020     Yes            No   349.00000             360.0
# 99   LP001343     Yes            No   131.00000             360.0
# 399  LP002287      No            No   103.00000             360.0
# 499  LP002602      No            No   209.00000             360.0

# %%
cr.iloc[[0,9,99,399,499],:]
# Out:
#       Loan_ID  Gender Married  Dependents Education Self_Employed  \
# 0    LP001002    Male      No         0.0  Graduate            No
# 9    LP001020    Male     Yes         1.0  Graduate            No
# 99   LP001343    Male     Yes         0.0  Graduate            No
# 399  LP002287  Female      No         0.0  Graduate            No
# 499  LP002602    Male      No         0.0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0   142.51153             360.0
# 9              12841            10968.0   349.00000             360.0
# 99              1759             3541.0   131.00000             360.0
# 399             1500             1800.0   103.00000             360.0
# 499             6283             4416.0   209.00000             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 9               1.0     Semiurban           N
# ...

# %%
cr.iloc[:,[1,4,6]]
# Out:
#     Gender     Education  ApplicantIncome
# 0     Male      Graduate             5849
# 1     Male      Graduate             4583
# 2     Male      Graduate             3000
# 3     Male  Not Graduate             2583
# 4     Male      Graduate             6000
# ..     ...           ...              ...
# 976   Male  Not Graduate             4009
# 977   Male      Graduate             4158
# 978   Male      Graduate             3250
# 979   Male      Graduate             5000
# 980   Male      Graduate             9200
#
# [981 rows x 3 columns]

# %% [markdown]
# # till now we have selected dta on index position but we can also select based on names

# %%
cr4 = cr.loc[:,['Gender','Education','ApplicantIncome']]

# %%
cr4.head()
# Out:
#   Gender     Education  ApplicantIncome
# 0   Male      Graduate             5849
# 1   Male      Graduate             4583
# 2   Male      Graduate             3000
# 3   Male  Not Graduate             2583
# 4   Male      Graduate             6000

# %%
cr4.shape
# Out:
# (981, 3)

# %%
# lets select record based on the condition

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0   142.51153             360.0
# 1             4583             1508.0   128.00000             360.0
# 2             3000                0.0    66.00000             360.0
# 3             2583             2358.0   120.00000             360.0
# 4             6000                0.0   141.00000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr5 = cr[cr.ApplicantIncome >= 3000]

# %%
cr5.shape
# Out:
# (703, 13)

# %%
cr.shape
# Out:
# (981, 13)

# %%
cr5.ApplicantIncome.describe()
# Out:
# count      703.000000
# mean      6321.937411
# std       6367.785835
# min       3000.000000
# 25%       3648.000000
# 50%       4583.000000
# 75%       6391.500000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
cr5.ApplicantIncome.min()
# Out:
# 3000

# %%
cr6 = cr[(cr.ApplicantIncome > 3000) & (cr.Education == 'Graduate')]

# %%
cr6.Education.value_counts()
# Out:
# Graduate    573
# Name: Education, dtype: int64

# %%
# drop Function can be used to drop our columns

# %%
cr7 = cr.drop(['Loan_ID'], axis = 1)
#axis = 1 implies i want to run drop function on columns

# %%
cr.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#drop can be used to drop more than one columns

# %%
cr32 = cr.drop(['Loan_ID','Gender','ApplicantIncome'], axis = 1)

# %%
cr32
# Out:
#     Married  Dependents     Education Self_Employed  CoapplicantIncome  \
# 0        No         0.0      Graduate            No                0.0
# 1       Yes         1.0      Graduate            No             1508.0
# 2       Yes         0.0      Graduate           Yes                0.0
# 3       Yes         0.0  Not Graduate            No             2358.0
# 4        No         0.0      Graduate            No                0.0
# ..      ...         ...           ...           ...                ...
# 976     Yes         4.0  Not Graduate           Yes             1777.0
# 977     Yes         0.0      Graduate            No              709.0
# 978      No         0.0      Graduate            No             1993.0
# 979     Yes         0.0      Graduate            No             2393.0
# 980      No         0.0      Graduate           Yes                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# ...

# %%
cr.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## Groupby

# %% [markdown]
# Problem Statement(If i want to analise is there any difference in-come of graduates and Non Graduates)

# %%
# group_by = cr.groupby([cr.ApplicantIncome, cr.Education])

# %%
cr.groupby('Education').ApplicantIncome.mean()
# Out:
# Education
# Graduate        5602.440367
# Not Graduate    3700.536697
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby('Education').ApplicantIncome.mean().round(2) #roud it to no of decimal postions
# Out:
# Education
# Graduate        5602.44
# Not Graduate    3700.54
# Name: ApplicantIncome, dtype: float64

# %%
# groupby more tahn one columns

# %%
cr.groupby('Gender').ApplicantIncome.mean()
# Out:
# Gender
# Female    4458.906593
# Male      5344.002503
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby(['Education','Gender']).ApplicantIncome.mean().round()
# Out:
# Education     Gender
# Graduate      Female    4598.0
#               Male      5844.0
# Not Graduate  Female    3853.0
#               Male      3672.0
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby(['Education','Gender']).ApplicantIncome.median().round()
# Out:
# Education     Gender
# Graduate      Female    3666.0
#               Male      4116.0
# Not Graduate  Female    3016.0
#               Male      3345.0
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby(['Education','Gender','Self_Employed']).ApplicantIncome.median().round()
# Out:
# Education     Gender  Self_Employed
# Graduate      Female  No               3655.0
#                       Yes              4166.0
#               Male    No               3973.0
#                       Yes              5417.0
# Not Graduate  Female  No               2599.0
#                       Yes              6166.0
#               Male    No               3276.0
#                       Yes              3808.0
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby('Education').mean().round() # mean for each and every Numeric columns
# Out:
#               Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Education
# Graduate             1.0           5602.0             1690.0       149.0
# Not Graduate         1.0           3701.0             1295.0       119.0
#
#               Loan_Amount_Term  Credit_History
# Education
# Graduate                 343.0             1.0
# Not Graduate             339.0             1.0

# %% [markdown]
# # Lets combine Groupby with Aggregate

# %%
cr.groupby(['Education']).ApplicantIncome.agg(['mean','max','min','median','count','std']).round()
# Out:
#                 mean    max  min  median  count     std
# Education
# Graduate      5602.0  81000    0    4000    763  6295.0
# Not Graduate  3701.0  18165    0    3333    218  2121.0

# %%
cr.groupby(['Education','Gender']).ApplicantIncome.agg(['mean','max','min','median','count','std']).round()
# Out:
#                        mean    max  min  median  count     std
# Education    Gender
# Graduate     Female  4598.0  19484  416  3666.0    148  3119.0
#              Male    5844.0  81000    0  4116.0    615  6823.0
# Not Graduate Female  3853.0  18165    0  3016.0     34  3790.0
#              Male    3672.0  13083  570  3345.0    184  1655.0

# %%
pd.set_option('display.max_columns',None)
cr.groupby(['Education']).agg(['mean','max','min','median','count','std']).round()
# Out:
#              Dependents                             ApplicantIncome         \
#                    mean  max  min median count  std            mean    max
# Education
# Graduate            1.0  4.0  0.0    0.0   763  1.0          5602.0  81000
# Not Graduate        1.0  4.0  0.0    0.0   218  1.0          3701.0  18165
#
#                                       CoapplicantIncome                        \
#              min median count     std              mean      max  min  median
# Education
# Graduate       0   4000   763  6295.0            1690.0  41667.0  0.0  1030.0
# Not Graduate   0   3333   218  2121.0            1295.0  13983.0  0.0  1271.0
#
#                            LoanAmount                                  \
#              count     std       mean    max   min median count   std
# Education
# Graduate       763  2967.0      149.0  700.0   9.0  132.0   763  83.0
# Not Graduate   218  1532.0      119.0  279.0  25.0  120.0   218  38.0
#
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
cr
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# 5    LP001011    Male     Yes         2.0      Graduate           Yes
# 6    LP001013    Male     Yes         0.0  Not Graduate            No
# 7    LP001014    Male     Yes         4.0      Graduate            No
# 8    LP001018    Male     Yes         2.0      Graduate            No
# 9    LP001020    Male     Yes         1.0      Graduate            No
# 10   LP001024    Male     Yes         2.0      Graduate            No
# 11   LP001027    Male     Yes         2.0      Graduate           Yes
# ...

# %% [markdown]
#  # replace Function

# %%
cr.Gender = cr.Gender.replace({'Male':0, 'Female':1})

# %%
cr.head()
# Out:
#     Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002       0      No         0.0      Graduate            No
# 1  LP001003       0     Yes         1.0      Graduate            No
# 2  LP001005       0     Yes         0.0      Graduate           Yes
# 3  LP001006       0     Yes         0.0  Not Graduate            No
# 4  LP001008       0      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0   142.51153             360.0
# 1             4583             1508.0   128.00000             360.0
# 2             3000                0.0    66.00000             360.0
# 3             2583             2358.0   120.00000             360.0
# 4             6000                0.0   141.00000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.Married = cr.Married.replace({'Yes':1, 'No':0})

# %%
cr.Self_Employed = cr.Self_Employed.replace({'Yes':1, 'No':0})

# %%
cr.Property_Area = cr.Property_Area.replace({'Urban':1,'Rural':0})

# %%
cr.Loan_Status = cr.Loan_Status.replace({'Y':1,'N':0})

# %% [markdown]
# # Encoding Techiques

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
## Another Method to convert Non numeric to Numeric
# Techinique (One Hot Encoding) -->> Dummy Variable Categoriztion but over here the number of columns will Increase
# where 1  will indicate the presence and 0 will indicate absense

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr = cr.iloc[:,1::] # to remove Loan_id
cr.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0      Graduate            No             5849
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
cr1 = pd.get_dummies(cr)

# %%
print(cr.shape)
print(cr1.shape)
# Out:
# (981, 12)
# (981, 19)

# %%
cr1.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0         0.0             5849                0.0         NaN
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 0             360.0             1.0              0            1           1
# 1             360.0             1.0              0            1           0
# 2             360.0             1.0              0            1           0
# 3             360.0             1.0              0            1           0
# 4             360.0             1.0              0            1           1
#
#    Married_Yes  Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# ...

# %% [markdown]
# # lets see one more method in which we can convert non numeric to numeric using LabelEncoding

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
# sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() #Created Object of Label Encoder so that functions can get attached to it

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.Gender = le.fit_transform(cr.Gender)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-3a3773ba51f4> in <module>
# ----> 1 cr.Gender = le.fit_transform(cr.Gender)
#
# ...

# %%
cr.Married = le.fit_transform(cr.Married)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-8624c8601ed0> in <module>
# ----> 1 cr.Married = le.fit_transform(cr.Married)
#
# ...

# %%
cr.Education = le.fit_transform(cr.Education)

# %%
cr.info()

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
cr.select_dtypes(include=['object']).columns

# %%
cr[cr.select_dtypes(include=['object']).columns]

# %%
# Now Aim is to convert Non Numeric into Numeric in a single line of code using Label Encoder

# %%
cr.Credit_History = cr.Credit_History.fillna(1)
cr.Gender = cr.Gender.fillna('Male')
cr.Married = cr.Married.fillna('No')
cr.Dependents = cr.Dependents.fillna(0)
cr.Self_Employed = cr.Self_Employed.fillna('Yes')
cr.LoanAmount = cr.LoanAmount.fillna(cr.LoanAmount.mean())
cr.Loan_Amount_Term = cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean())

# %%
cr = cr.iloc[:,1::]

# %%
cr.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cr[cr.select_dtypes(include='object').columns] = cr[cr.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
#Cross Table

# %%
## PS: Is there any role of Education in Loan Approval or not

# %%
pd.crosstab(cr.Education, cr.Loan_Status)
# Out:
# Loan_Status    0    1
# Education
# 0            196  567
# 1             73  145

# %%
pd.crosstab(cr.Gender, cr.Loan_Status)
# Out:
# Loan_Status    0    1
# Gender
# 0             55  127
# 1            214  585

# %%
pd.crosstab(cr.Self_Employed, cr.Loan_Status)
# Out:
# Loan_Status      0    1
# Self_Employed
# 0              220  587
# 1               49  125

# %%
# percentile Function

# %%
cr.ApplicantIncome.describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count      981.000000
# mean      5179.795107
# std       5695.104533
# min          0.000000
# 10%       2221.000000
# 20%       2609.000000
# 30%       3062.000000
# 40%       3413.000000
# 50%       3800.000000
# 60%       4301.000000
# 70%       5000.000000
# 80%       6080.000000
# 90%       8750.000000
# 100%     81000.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
# Co-relation Matrix ... range of Co-relation is (-1 to 1)

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
cr.corr().round(3)
# Out:
#                    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Dependents              1.000            0.138             -0.003       0.150
# ApplicantIncome         0.138            1.000             -0.114       0.552
# CoapplicantIncome      -0.003           -0.114              1.000       0.179
# LoanAmount              0.150            0.552              0.179       1.000
# Loan_Amount_Term       -0.088           -0.023             -0.044       0.056
# Credit_History         -0.058            0.023             -0.027      -0.008
#
#                    Loan_Amount_Term  Credit_History
# Dependents                   -0.088          -0.058
# ApplicantIncome              -0.023           0.023
# CoapplicantIncome            -0.044          -0.027
# LoanAmount                    0.056          -0.008
# Loan_Amount_Term              1.000          -0.020
# Credit_History               -0.020           1.000

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
c1 = cr[cr.ApplicantIncome >=4500]

# %%
c1.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  354.000000       364.000000         364.000000  351.000000
# mean     1.076271      8807.038462        1141.662088  185.689459
# std      1.345374      8087.767129        2198.969094  102.104976
# min      0.000000      4500.000000           0.000000   26.000000
# 25%      0.000000      5183.000000           0.000000  125.000000
# 50%      1.000000      6280.000000           0.000000  158.000000
# 75%      2.000000      9167.000000        1651.000000  208.500000
# max      4.000000     81000.000000       14507.000000  700.000000
#
#        Loan_Amount_Term  Credit_History
# count        356.000000      342.000000
# mean         344.123596        0.859649
# std           59.364013        0.347860
# min           12.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %%
#annother Way
#Using Query method

# %%
cr2.ApplicantIncome.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-3c3ce947442e> in <module>
# ----> 1 cr2.ApplicantIncome.describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ApplicantIncome'

# %%
cr2 = cr.query('ApplicantIncome > 4500')

# %%
cr3 = cr.query("Education == 'Graduate'")

# %%
cr3.Education.value_counts()
# Out:
# Graduate    763
# Name: Education, dtype: int64

# %%
cr4 = cr.query(('Gender == "Male" & ApplicantIncome > 4000'))

# %%
cr4.Gender.value_counts()
# Out:
# Male    363
# Name: Gender, dtype: int64

# %%
cr4.ApplicantIncome.describe()
# Out:
# count      363.000000
# mean      7940.176309
# std       7665.139159
# min       4006.000000
# 25%       4746.000000
# 50%       5829.000000
# 75%       8076.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
# Create a dtframe which select all the numeric columns from this cr dataframe

# %%
cr5 = cr[cr.select_dtypes(include =['int','float']).columns]
cr5.head()
# Out:
#    Dependents  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 0         0.0                0.0         NaN             360.0             1.0
# 1         1.0             1508.0       128.0             360.0             1.0
# 2         0.0                0.0        66.0             360.0             1.0
# 3         0.0             2358.0       120.0             360.0             1.0
# 4         0.0                0.0       141.0             360.0             1.0

# %% [markdown]
# # Different ways of reading file

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv', usecols=['ApplicantIncome','Gender','LoanAmount'])

# %%
cr.head()
# Out:
#   Gender  ApplicantIncome  LoanAmount
# 0   Male             5849         NaN
# 1   Male             4583       128.0
# 2   Male             3000        66.0
# 3   Male             2583       120.0
# 4   Male             6000       141.0

# %% [markdown]
# # To read file without using read_csv .. read it using clipbaord

# %%
cr_clip = pd.read_clipboard()

# %%
cr_clip
# Out:
#       new_income     = 2*cr.ApplicantIncome             # new_income.1    is  \
# 0         cr_new     =       pd.concat([cr,  new_income],         axis     =
# 1  cr_new.head()  None                 None          None         None  None
#
#     new   c
# 0    1) NaN
# 1  None NaN

# %%
# sort Data in ascending or descending order
# PS i want to sort income in descending

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')

# %%
cr_sort = cr.sort_values('ApplicantIncome', ascending=True)

# %%
cr.sort_values('ApplicantIncome', ascending=False)
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         4.0      Graduate            No
# 695  LP001428    Male     Yes         4.0      Graduate            No
# 333  LP002101    Male     Yes         0.0      Graduate           NaN
# 171  LP001585     NaN     Yes         4.0      Graduate            No
# 155  LP001536    Male     Yes         4.0      Graduate            No
# 185  LP001640    Male     Yes         0.0      Graduate           Yes
# 443  LP002422    Male      No         1.0      Graduate            No
# 183  LP001637    Male     Yes         1.0      Graduate            No
# 757  LP001791    Male     Yes         0.0      Graduate           Yes
# 893  LP002553     NaN      No         0.0      Graduate            No
# 886  LP002485    Male      No         1.0      Graduate            No
# 126  LP001448     NaN     Yes         4.0      Graduate            No
# ...

# %% [markdown]
# # to add a new column in our DF

# %%
# the main condition to add new columns is dataframe(number of rows same as number of rows in df)

# lets consider the income f all the people is 2 times

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')
new_income = 2*cr.ApplicantIncome # new_income is new col

# %%
new_income
# Out:
# 0       11698
# 1        9166
# 2        6000
# 3        5166
# 4       12000
# 5       10834
# 6        4666
# 7        6072
# 8        8012
# 9       25682
# 10       6400
# 11       5000
# 12       6146
# 13       3706
# 14       2598
# 15       9900
# 16       7192
# 17       7020
# 18       9774
# 19       5200
# 20      15320
# 21      11910
# 22       5200
# 23       6730
# 24       7434
# 25      19120
# 26       5598
# 27       8452
# 28       2884
# 29       7500
# 30       8332
# 31       6334
# 32       9384
# 33       7000
# 34      25000
# 35       4550
# 36       3656
# 37       7334
# 38       8332
# 39       7496
# 40       7200
# 41       3600
# 42       4800
# 43       7882
# 44       9390
# 45       6820
# 46      11298
# 47      11642
# 48       5290
# 49       8000
# 50       3856
# 51       6172
# 52       8460
# 53       9232
# 54      23000
# 55       5416
# 56       4264
# 57       6732
# 58      16160
# 59       6714
# 60       5000
# 61       6058
# ...

# %%
cr['New_Income_col'] = new_income

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Income_col
# 0             1.0         Urban           Y           11698
# ...

# %%
# Another way to add column is to use concat

# %%
cr_new = pd.concat([cr, new_income], axis = 1)

# %%
cr_new.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Income_col  ApplicantIncome
# ...

# %%
# how to rename a columns

# %%
cr.rename(columns = {'ApplicantIncome':'AppInce'}, inplace=True)

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  AppInce  \
# 0  LP001002   Male      No         0.0      Graduate            No     5849
# 1  LP001003   Male     Yes         1.0      Graduate            No     4583
# 2  LP001005   Male     Yes         0.0      Graduate           Yes     3000
# 3  LP001006   Male     Yes         0.0  Not Graduate            No     2583
# 4  LP001008   Male      No         0.0      Graduate            No     6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  New_Income_col
# 0         Urban           Y           11698
# ...

# %%
# i can change name of ore than 1 column in single line

# %%
cr.rename(columns={'Gender':'Gen'}, inplace= True)

# %%
cr.rename(columns={'Education':'Edu', 'Self_Employed':'Self_Emp'}, inplace= True)

# %%
cr.head()
# Out:
#     Loan_ID   Gen Married  Dependents           Edu Self_Emp  AppInce  \
# 0  LP001002  Male      No         0.0      Graduate       No     5849
# 1  LP001003  Male     Yes         1.0      Graduate       No     4583
# 2  LP001005  Male     Yes         0.0      Graduate      Yes     3000
# 3  LP001006  Male     Yes         0.0  Not Graduate       No     2583
# 4  LP001008  Male      No         0.0      Graduate       No     6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  New_Income_col
# 0         Urban           Y           11698
# 1         Rural           N            9166
# ...

# %%
# another way to change column name without using column Name

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')
cr.head(2)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
# 1  LP001003   Male     Yes         1.0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
# Lets Take Gennder and Education col

# %%
cr.rename(columns={cr.columns[1]:'Gen',  cr.columns[4]:'Edu'}, inplace= True)
cr.head()
# Out:
#     Loan_ID   Gen Married  Dependents           Edu Self_Employed  \
# 0  LP001002  Male      No         0.0      Graduate            No
# 1  LP001003  Male     Yes         1.0      Graduate            No
# 2  LP001005  Male     Yes         0.0      Graduate           Yes
# 3  LP001006  Male     Yes         0.0  Not Graduate            No
# 4  LP001008  Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr = pd.read_csv('C:/Users/shubh/Downloads/CreditRisk.csv')
new_income = 2*cr.ApplicantIncome # new_income is new c
cr_new = pd.concat([cr, new_income], axis = 1)
cr_new.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  ApplicantIncome
# 0             1.0         Urban           Y            11698
# ...

# %%
cr_new.rename(columns={cr_new.columns[-1]:'New_Appli_Income'},inplace = True)

# %%
cr_new.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    New_Appli_Income  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Appli_Income
# 0             1.0         Urban           Y             11698
# ...

# %%
# how to change the names of columns when duplicate name exist.

# %%
new_income = 2*cr.ApplicantIncome # new_income is new c
cr_new = pd.concat([cr, new_income], axis = 1)
cr_new.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  ApplicantIncome
# 0             1.0         Urban           Y            11698
# ...

# %%
cr_new.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'ApplicantIncome'],
#       dtype='object')

# %%
type(cr_new.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
l1 = list(cr_new.columns)
# l1
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status',
#  'ApplicantIncome']

# %%
len(l1)
# Out:
# 14

# %%
l1[13] = 'New_Appli_Income'

# %%
cr_new.columns = l1

# %%
cr_new.head(2)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
# 1  LP001003   Male     Yes         1.0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Appli_Income
# 0             1.0         Urban           Y             11698
# 1             1.0         Rural           N              9166

# %%
import pandas as pd

# %%
date_time = pd.DataFrame({'date':('2018-1-28', '2019-10-28')})

# %%
date_time
# Out:
#          date
# 0   2018-1-28
# 1  2019-10-28

# %%
date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes

# %%
date_time.date = pd.to_datetime(data_time.date)

# date_time is name of DF and .date is column we are selecting from the data Frame

## using pd.to_datetime convert object column to date time format

# %%
date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 144.0 bytes

# %%
date_time['date'].dt.year
# Out:
# 0    2018
# 1    2019
# Name: date, dtype: int64

# %%
date_time['date'].dt.month
# Out:
# 0     1
# 1    10
# Name: date, dtype: int64

# %%
date_time['date'].dt.week
# Out:
# <ipython-input-197-abb7d72d7bc9>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   date_time['date'].dt.week
# 0     4
# 1    44
# Name: date, dtype: int64

# %%
date_time['date'].dt.day
# Out:
# 0    28
# 1    28
# Name: date, dtype: int64

# %%
date_time['Year'] = date_time['date'].dt.year

# %%
date_time
# Out:
#         date  Year
# 0 2018-01-28  2018
# 1 2019-10-28  2019

# %%
date_time['Month'] = data_time['date'].dt.month

# %%
date_time
# Out:
#         date  Year  Month
# 0 2018-01-28  2018      1
# 1 2019-10-28  2019     10

# %%
date_time['Day'] = date_time['date'].dt.day

# %%
date_time
# Out:
#         date  Year  Month  Day
# 0 2018-01-28  2018      1   28
# 1 2019-10-28  2019     10   28

# %%
df_date_time = pd.DataFrame({'DT':('2018-12-28 12:24:59',
                                   '2019-05-9 2:10:25',
                                   '2019-12-31 22:10:25',
                                   '2017-01-01 9:01:20',
                                  '2019-07-03 22:10:25')})

# %%
df_date_time
# Out:
#                     DT
# 0  2018-12-28 12:24:59
# 1    2019-05-9 2:10:25
# 2  2019-12-31 22:10:25
# 3   2017-01-01 9:01:20
# 4  2019-07-03 22:10:25

# %%
df_date_time.DT = pd.to_datetime(df_date_time.DT)

# %%
df_date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DT      5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 168.0 bytes

# %%
df_date_time['Year'] = df_date_time.DT.dt.year
df_date_time['Month_of_year'] = df_date_time.DT.dt.month
df_date_time['Day_of_Month'] = df_date_time.DT.dt.day
df_date_time['Hour_of_Day'] = df_date_time.DT.dt.hour
df_date_time['Minutes'] = df_date_time.DT.dt.minute
df_date_time['second'] = df_date_time.DT.dt.second

# %%
df_date_time
# Out:
#                    DT  Year  Month_of_year  Day_of_Month  Hour_of_Day  \
# 0 2018-12-28 12:24:59  2018             12            28           12
# 1 2019-05-09 02:10:25  2019              5             9            2
# 2 2019-12-31 22:10:25  2019             12            31           22
# 3 2017-01-01 09:01:20  2017              1             1            9
# 4 2019-07-03 22:10:25  2019              7             3           22
#
#    Minutes  second
# 0       24      59
# 1       10      25
# 2       10      25
# 3        1      20
# 4       10      25

# %%
#lets create a dataframe which doees noot dates in proper format

# %%
invalid_time = pd.DataFrame({'DT':('20150112',
                                  '4570',
                                  '201A/10/11',
                                  '20160919')})

# %%
invalid_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DT      4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
invalid_time.DT = pd.to_datetime(invalid_time.DT, errors = 'ignore') # raise means error will be shown and executions stops

# %%
invalid_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DT      4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
invalid_time.DT = pd.to_datetime(invalid_time.DT, errors = 'coerce')
invalid_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DT      2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
invalid_time.DT
# Out:
# 0   2015-01-12
# 1          NaT
# 2          NaT
# 3   2016-09-19
# Name: DT, dtype: datetime64[ns]

# %%
invalid_time.DT = invalid_time.DT.fillna('2015-01-01')

# %%
invalid_time
# Out:
#                     DT
# 0  2015-01-12 00:00:00
# 1           2015-01-01
# 2           2015-01-01
# 3  2016-09-19 00:00:00

# %%
import pyforest

# %%
df = pd.read_csv('SearchTrendData_WithMissing.csv')

# %%
df.isnull().sum()
# Out:
# Week                       0
# eLearning                 16
# DataScience               12
# MachineLearning            7
# ArtificialIntelligence     6
# DeepLearning              11
# dtype: int64

# %%
df[df.isnull().any(axis = 1)]
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 5    25/10/2015       38.0         10.0              NaN
# 10   29/11/2015        NaN          9.0             13.0
# 12   13/12/2015       30.0          9.0             14.0
# 20    7/02/2016       28.0         10.0              NaN
# 22   21/02/2016        NaN         10.0             14.0
# 24    6/03/2016       30.0         10.0             15.0
# 28    3/04/2016       29.0         10.0             15.0
# 29   10/04/2016        NaN         10.0             14.0
# 35   22/05/2016       27.0          NaN             16.0
# 45   31/07/2016       18.0         11.0             15.0
# 61   20/11/2016        NaN         12.0             21.0
# 63    4/12/2016       30.0         13.0             22.0
# 66   25/12/2016       17.0          NaN             15.0
# 67    1/01/2017       21.0         13.0             20.0
# 73   12/02/2017        NaN         15.0             25.0
# ...

# %%
df['eLearning'].fillna(df['eLearning'].mean())
# Out:
# 0      32.0
# 1      35.0
# 2      38.0
# 3      37.0
# 4      38.0
#        ...
# 256    41.0
# 257    49.0
# 258    62.0
# 259    74.0
# 260    80.0
# Name: eLearning, Length: 261, dtype: float64

# %%
df.fillna(method='pad')
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 0    20/09/2015       32.0          9.0             11.0
# 1    27/09/2015       35.0         10.0             11.0
# 2     4/10/2015       38.0         10.0             12.0
# 3    11/10/2015       37.0          9.0             12.0
# 4    18/10/2015       38.0          9.0             12.0
# ..          ...        ...          ...              ...
# 256  16/08/2020       41.0         36.0             40.0
# 257  23/08/2020       49.0         39.0             40.0
# 258  30/08/2020       62.0         37.0             40.0
# 259   6/09/2020       74.0         37.0             42.0
# 260  13/09/2020       80.0         39.0             39.0
#
#      ArtificialIntelligence  DeepLearning
# 0                      11.0           4.0
# 1                      11.0           4.0
# 2                      11.0           4.0
# 3                      10.0           4.0
# 4                      10.0           4.0
# ...

# %%
df.fillna(method='backfill')
# Out:
#            Week  eLearning  DataScience  MachineLearning  \
# 0    20/09/2015       32.0          9.0             11.0
# 1    27/09/2015       35.0         10.0             11.0
# 2     4/10/2015       38.0         10.0             12.0
# 3    11/10/2015       37.0          9.0             12.0
# 4    18/10/2015       38.0          9.0             12.0
# ..          ...        ...          ...              ...
# 256  16/08/2020       41.0         36.0             40.0
# 257  23/08/2020       49.0         39.0             40.0
# 258  30/08/2020       62.0         37.0             40.0
# 259   6/09/2020       74.0         39.0             42.0
# 260  13/09/2020       80.0         39.0             39.0
#
#      ArtificialIntelligence  DeepLearning
# 0                      11.0           4.0
# 1                      11.0           4.0
# 2                      11.0           4.0
# 3                      10.0           4.0
# 4                      10.0           4.0
# ...
